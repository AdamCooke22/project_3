# %% [markdown]
# <a href="https://colab.research.google.com/github/AdamCooke22/project_3/blob/main/Topics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pygooglenews --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 362 kB 16.8 MB/s
# ...
#      |████████████████████████████████| 128 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 47.3 MB/s
# ...
#      |████████████████████████████████| 62 kB 590 kB/s
# ...
#   Created wheel for feedparser: filename=feedparser-5.2.1-py3-none-any.whl size=44951 sha256=2f193cb4574622979004fa0458071e46f63a43e5651711f9728be84f040e2ee2
#   Stored in directory: /root/.cache/pip/wheels/67/38/07/59c89c3d334e7f1f743898af6d21c15ecb3588ad04af7ddee0
# Successfully built feedparser
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...

# %%
from pygooglenews import GoogleNews

gn = GoogleNews()

import pandas as pd

# %%
business = gn.topic_headlines('business')

# %%
print(business)
# Out:
# {'feed': {'generator_detail': {'name': 'NFE/5.0'}, 'generator': 'NFE/5.0', 'title': 'Business - Latest - Google News', 'title_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': 'Business - Latest - Google News'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB?ceid=US:en&hl=en-US&gl=US'}], 'link': 'https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB?ceid=US:en&hl=en-US&gl=US', 'language': 'en-US', 'publisher': 'news-webmaster@google.com', 'publisher_detail': {'email': 'news-webmaster@google.com'}, 'rights': '2022 Google Inc.', 'rights_detail': {'type': 'text/plain', 'language': None, 'base': '', 'value': '2022 Google Inc.'}, 'updated': 'Thu, 01 Dec 2022 01:15:44 GMT', 'updated_parsed': time.struct_time(tm_year=2022, tm_mon=12, tm_mday=1, tm_hour=1, tm_min=15, tm_sec=44, tm_wday=3, tm_yday=335, tm_isdst=0), 'subtitle': 'Google New
# ...

# %%
world = gn.topic_headlines('world')

# %%
nation = gn.topic_headlines('nation')

# %%
technology = gn.topic_headlines('technology')
